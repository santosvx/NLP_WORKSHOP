# %%
# Getting Started

# import what we need
import pandas as pd
from pandas import DataFrame as DF, Series

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from textblob import TextBlob

# %%
# read data
cols = ['airline_sentiment','airline_sentiment_confidence',
        'airline','name','text']
data = pd.read_csv('tweets.csv', usecols=cols)

# Below is the first 5 rows of our data. We will only be using the first two features, and the last feature.

# %%
data.head()
# Out:
#   airline_sentiment  airline_sentiment_confidence         airline        name  \
# 0           neutral                        1.0000  Virgin America     cairdin
# 1          positive                        0.3486  Virgin America    jnardino
# 2           neutral                        0.6837  Virgin America  yvonnalynn
# 3          negative                        1.0000  Virgin America    jnardino
# 4          negative                        1.0000  Virgin America    jnardino
#
#                                                 text
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...

# %%
# Polarity & Subjectivity Using TextBlob sentiment
# Basic Sentiment Analysis
# Using the TextBlob sentiment method
# TextBlob has a sentiment method that can be used on any TextBlob object. It returns two values:

# polarity: value in range [-1, 1], indicating how negative or positive the text is (close to 0.0 is neutral).
# subjectivity: value in range [0, 1], indicating how subjective the text is (1 is very subjective)
# This method is very basic, and there is a lot to be desired, but it can still be helpful if you don't have opportunity to train a classifier, and just need some rough results.

lines = ["The food is on the table", "The food is green", "I don't like the food",
         "I do not like the food", "I like the food", "I don't love the food", "I do not love the food",
         "I hate the food", "I love the food", "The food is delicious"]

# analyze the sentences
sentiments = [b.sentiment for b in [TextBlob(l) for l in lines]]
for l,s in zip(lines, sentiments):
    print('{} \n(p={}, s={})'.format(l, s[0], s[1]), '\n')
    
# As seen above, this method doesn't recognize negative contractions (e.g. don't), and it has trouble with ambiguous works that can take on multiple meanings (e.g. like, which is also used for comparision)

# Let's see how it does with a couple book reviews.
# Out:
# The food is on the table
# (p=0.0, s=0.0)
#
# The food is green
# (p=-0.2, s=0.3)
#
# I don't like the food
# (p=0.0, s=0.0)
#
# I do not like the food
# (p=0.0, s=0.0)
#
# I like the food
# (p=0.0, s=0.0)
#
# I don't love the food
# (p=0.5, s=0.6)
#
# I do not love the food
# (p=-0.25, s=0.6)
#
# I hate the food
# (p=-0.8, s=0.9)
#
# I love the food
# (p=0.5, s=0.6)
#
# The food is delicious
# (p=1.0, s=1.0)

# %%
# Using The sentiment Method on Tweets
# We will get a subset of our data that contains only the first 10 rows that have a confidence level greater that 0.6. This is because we are uninterested in entries with a high level of uncertainty, because keeping low-confidence observations would reduce the certainty of evaluations that we will make later.

subset = data[data.airline_sentiment_confidence > 0.6]\
    .head(10).copy().reset_index(drop=True)
tweets = subset.text

# %%
subset
# Out:
#   airline_sentiment  airline_sentiment_confidence         airline  \
# 0           neutral                        1.0000  Virgin America
# 1           neutral                        0.6837  Virgin America
# 2          negative                        1.0000  Virgin America
# 3          negative                        1.0000  Virgin America
# 4          negative                        1.0000  Virgin America
# 5          positive                        0.6745  Virgin America
# 6           neutral                        0.6340  Virgin America
# 7          positive                        0.6559  Virgin America
# 8          positive                        1.0000  Virgin America
# 9           neutral                        0.6769  Virgin America
#
#               name                                               text
# 0          cairdin                @VirginAmerica What @dhepburn said.
# 1       yvonnalynn  @VirginAmerica I didn't today... Must mean I n...
# 2         jnardino  @VirginAmerica it's really aggressive to blast...
# 3         jnardino  @VirginAmerica and it's a really big bad thing...
# 4         jnardino  @VirginAmerica seriously would pay $30 a fligh...
# 5       cjmcginnis  @VirginAmerica yes, nearly every time I fly VX...
# 6            pilot  @VirginAmerica Really missed a prime opportuni...
# 7         dhepburn    @virginamerica Well, I didn't…but NOW I DO! :-D
# 8       YupitsTate  @VirginAmerica it was amazing, and arrived an ...
# 9  idk_but_youtube  @VirginAmerica did you know that suicide is th...

# %%
# Compare the sentiment predictions with each line in subset
# We want to get a sense of how each tweet is being classified

# print the tweets and predicted polarity line-by-line
for i,t in enumerate(tweets):
    s = TextBlob(t).sentiment
    target = subset.airline_sentiment[i]
    print(t, '\n', '{} (target: {}) \n'.format(s[0], target))
    
# This basic sentiment analyzer missed the mark on 3/10 tweets (2 neutral and 1 negative). That's not too bad, but these results are nothing to celebrate. The perfmance declines quite a bit with larger texts.

# Looking at the two tweets the sentiment method estimated incorrectly:

# @VirginAmerica I didn't today... Must mean I need to take another trip! This one is interpreted by the computer as negative, and perhaps it's correct. This one is full of ambiguity without any context, and that is probably why the target value in the set is neutral.

# @VirginAmerica it's really aggressive to blast obnoxious "entertainment" in your guests' faces & they have little recourse This one is
# Out:
# @VirginAmerica What @dhepburn said.
#  0.0 (target: neutral)
#
# @VirginAmerica I didn't today... Must mean I need to take another trip!
#  -0.390625 (target: neutral)
#
# @VirginAmerica it's really aggressive to blast obnoxious "entertainment" in your guests' faces &amp; they have little recourse
#  0.0062500000000000056 (target: negative)
#
# @VirginAmerica and it's a really big bad thing about it
#  -0.3499999999999999 (target: negative)
#
# @VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.
# it's really the only bad thing about flying VA
#  -0.2083333333333333 (target: negative)
#
# @VirginAmerica yes, nearly every time I fly VX this “ear worm” won’t go away :)
#  0.4666666666666666 (target: positive)
#
# @VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP
#  0.2 (target: neutral)
#
# @virginamerica Well, I didn't…but NOW I DO! :-D
#  1.0 (target: positive)
#
# @VirginAmerica it was amazing, and arrived an hour early. You're too good to me.
#  0.4666666666666666 (target: positive)
#
# @VirginAmerica did you know that suicide is the second leading cause of death among teens 10-24
#  0.0 (target: neutral)

# %%
# Analyze polarity of each word in the last sentence above to see what's happening

words = TextBlob(tweets[2]).words
for w in words: print(w, TextBlob(w).sentiment[0], '\n')
    
# We can see that the sentiment method does not consider the words "obnoxious" or "aggressive" to be negative, which is a glaring problem for our analysis. This method is clearly limited and we need a better method.
# Out:
# VirginAmerica 0.0
#
# it 0.0
#
# 's 0.0
#
# really 0.2
#
# aggressive 0.0
#
# to 0.0
#
# blast 0.0
#
# obnoxious 0.0
#
# entertainment 0.0
#
# in 0.0
#
# your 0.0
#
# guests 0.0
#
# faces 0.0
#
# amp 0.0
#
# they 0.0
#
# have 0.0
#
# little -0.1875
#
# recourse 0.0

# %%
# Create train and test sets
# train the model on the first set
# test/evaluate it on the other
# The set below named reduced is reduced in dimensionality (keeping only the features/columns we care about).

# The train and test sets are created using something called a list comprehension. If you don't know what that is, it's okay, and you can look it up later. What is important is to know that the Naive Bayes classifier takes data in the form of a list of doubles, where each double is one observation (text, label), where label is the class label that belongs to the text.


# get reduced set
reduced = data.ix[:, ['airline_sentiment','text']].copy()
reduced.rename(columns={'airline_sentiment': 'target'}, inplace=1)

# now create train and test sets for first 500 tweets
# for the TextBlob classifier we need a list of doubles (string, target)
train = [(s, t) for s,t in zip(reduced.iloc[:350].text, reduced.iloc[:350].target)]
test = [(s, t) for s,t in zip(reduced.iloc[350:500].text, reduced.iloc[350:500].target)]
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.

# %%
# import the classifier
from textblob.classifiers import NaiveBayesClassifier

# train
cl = NaiveBayesClassifier(train)
# evaluate
cl.accuracy(test)
# Out:
# 0.6266666666666667

# %%
# a quick look at the distribution of class labels
reduced.target.value_counts()
# Out:
# negative    9178
# neutral     3099
# positive    2363
# Name: target, dtype: int64

# %%
# create a score function that will give precision and recall values for each class
def score(true, predicted):
    eq = np.equal
    
    t = np.array(true)
    p = np.array(predicted)
    
    tp = np.array([eq((t == c)*(p == c), 1).sum() for c in np.unique(t)])
    fp = np.array([eq((t != c)*(p == c), 1).sum() for c in np.unique(t)])
    fn = np.array([eq((t == c)*(p != c), 1).sum() for c in np.unique(t)])

    precision = tp/(tp + fp)
    recall = tp/(tp + fn)
    
    return (np.unique(t), precision, recall)

# %%
# Evaluate classifier on larger set
# * skip this; takes too long *

# With train/test split

# create new train and test sets
# for the TextBlob classifier we need a list of doubles (string, target)

train = [(s, t) for s,t in zip(reduced.iloc[:1500].text, reduced.iloc[:1500].target)]
test = [(s, t) for s,t in zip(reduced.iloc[1500:2000].text, reduced.iloc[1500:2000].target)]

# %%
# train
cl = NaiveBayesClassifier(train)

# evaluate
cl.accuracy(test)
# 0.786
# Out:
# 0.788

# %%
# Naive Bayes Classifier: Digging Deeper
# Making Predictions
# NaiveBayesClassifier has a classify method that takes text (a single string) as an argument. This means that we can either classify some string that we choose to type by hand, or classify tweets from our test set individually.

cl.classify('I love this airline')
# Out:
# 'positive'

# %%
# Getting class probabilities

probs = cl.prob_classify('I love this airline')
probs.max()
# Out:
# 'positive'

# %%
probs.prob('positive')
# Out:
# 0.62832147146215

# %%
probs.prob('negative')

# The above can be useful if you want to make modifications to how something is classified by setting a threshold. For example, you may want to only classify something as positive if the probability exceeds 0.9, instead of it simply having the highest probability.
# Out:
# 0.06092324050268474

# %%
# Informative Features
# The method below gives us some insight into how the classifier is making decisions. For example, we can see that if a string contains the word "great", the there is are 8.7:1 odds that the string is positive instead of negative. All of the features are taken into account for one string, so that doesn't mean just because "great" is in the string it will be classified as positive.

cl.show_informative_features(10)

# How to interpret this:

# We are given rows that have contains(feature) = True/False and a comparison of two class labels with a ratio that indicates how likely one is over the other
# The printed results are in descending order of importance
# Ex: contains(no) = True gives the ratio of 9.7 : 1.0, showing that it is extremely likely to be negative rather than neutral
# The default features for the Naive Bayes classifier are individual words found in the data
# Out:
# Most Informative Features
#          contains(thank) = True           positi : negati =     25.3 : 1.0
#             contains(no) = True           negati : positi =     21.0 : 1.0
#        contains(amazing) = True           positi : negati =     18.4 : 1.0
#           contains(love) = True           positi : negati =     16.2 : 1.0
#           contains(been) = True           negati : neutra =     14.0 : 1.0
#        contains(delayed) = True           negati : neutra =     13.3 : 1.0
#            contains(She) = True           positi : negati =     11.9 : 1.0
#          contains(Thank) = True           positi : negati =     10.3 : 1.0
#         contains(please) = True           neutra : positi =      9.8 : 1.0
#           contains(best) = True           positi : negati =      9.7 : 1.0

# %%
# Extracting Features
# We are provided a method that serves one purpose: take a string and return a dictionary of all features in our classifier (individual words by default), and whether or not that word is in the string. It is essentially a binary feature vector.

cl.extract_features('I have no idea where this flight is taking me')
# Out:
# {'contains(reinstated)': False,
#  'contains(face)': False,
#  'contains(mobile)': False,
#  'contains(illegal)': False,
#  'contains(TRUU_Tall)': False,
#  'contains(understaffed)': False,
#  'contains(nite)': False,
#  'contains(Just)': False,
#  'contains(copy/paste)': False,
#  'contains(impressed)': False,
#  'contains(airport_fra)': False,
#  'contains(afford)': False,
#  'contains(avoided)': False,
#  'contains(disability)': False,
#  'contains(Boston)': False,
#  'contains(Thankyou)': False,
#  'contains(Hey)': False,
#  'contains(saves)': False,
#  'contains(location)': False,
#  'contains(Really)': False,
#  'contains(Can)': False,
#  'contains(hard-earned)': False,
#  'contains(representatives)': False,
#  'contains(so)': False,
#  'contains(lostluggage)': False,
#  'contains(any)': False,
#  'contains(inept)': False,
#  'contains(LAS-DEN)': False,
#  'contains(mech)': False,
#  'contains(inadequate)': False,
#  'contains(POS)': False,
#  'contains(why)': False,
#  'contains(Rozana)': False,
#  'contains(Requested)': False,
#  'contains(reference)': False,
#  'contains(solved)': False,
#  'contains(hi)': False,
#  'contains(shoe)': False,
#  'contains(friends)': False,
#  'contains(Bergstrom)': False,
#  'contains(looking)': False,
#  'contains(Nashville)': False,
#  'contains(connectns)': False,
#  'contains(FYI)': False,
#  'contains(right)': False,
#  'contains(Still)': False,
#  'contains(bench)': False,
#  'contains(restr)': False,
#  'contains(T3)': False,
#  'contains(failing)': False,
#  'contains(😃👍)': False,
#  'contains(screws)': False,
#  'contains(clientNotHappy)': False,
#  'contains(did)': False,
#  'contains(able)': False,
#  'contains(heyyyy)': False,
#  'contains(inappropriate)': False,
#  'contains(ABQ)': False,
#  'contains(Douglas)': False,
#  'contains(sorted)': False,
#  'contains(shrinerack)': False,
#  'contains(ploughs)': False,
#  'contains(complain)': False,
#  'contains(downtown)': False,
#  'contains(Investor)': False,
#  'contains(wheel)': False,
#  'contains(errors)': False,
#  'contains(UA63)': False,
#  'contains(Rockies)': False,
#  'contains(8477733)': False,
#  'contains(unhelpful)': False,
#  'contains(female)': False,
#  'contains(freddieawards)': False,
#  'contains(t.co/oAflfr7WXB)': False,
#  'contains(consistently)': False,
#  'contains(her)': False,
#  'contains(resolve)': False,
#  'contains(disputed)': False,
#  'contains(row)': False,
#  'contains(employee)': False,
#  'contains(DM)': False,
#  'contains(sock)': False,
#  'contains(howisthatpossible)': False,
#  'contains(choppy)': False,
#  'contains(adds)': False,
#  'contains(mistakes)': False,
#  'contains(believe)': False,
#  'contains(reasons)': False,
#  'contains(FastCompany)': False,
#  'contains(919)': False,
#  'contains(passes)': False,
#  'contains(RECEIPT)': False,
#  'contains(general)': False,
#  'contains(profit)': False,
#  'contains(CX)': False,
#  'contains(got)': False,
#  'contains(Sunday)': False,
#  'contains(Tues)': False,
#  'contains(Actually)': False,
#  'contains(dfpietra)': False,
#  'contains(problems)': False,
#  'contains(each)': False,
#  'contains(skift)': False,
#  'contains(spousal.discrimination/angry)': False,
#  'contains(rain)': False,
#  'contains(pull)': False,
#  'contains(breakfast)': False,
#  'contains(included)': False,
#  'contains(albanyairport)': False,
#  'contains(normal)': False,
#  'contains(answered)': False,
#  'contains(reservation)': False,
#  'contains(964078)': False,
#  'contains(BOS)': False,
#  'contains(reFlight)': False,
#  'contains(Michelle)': False,
#  'contains(787)': False,
#  'contains(goodenufmother)': False,
#  'contains(35A)': False,
#  'contains(transformative)': False,
#  'contains(fl1289)': False,
#  'contains(16866853)': False,
#  'contains(connected)': False,
#  'contains(wjere)': False,
#  'contains(defiantly)': False,
#  'contains(scheduled)': False,
#  'contains(FlightR)': False,
#  'contains(list)': False,
#  'contains(t.co/ybMbGs0dHn)': False,
#  'contains(looks)': False,
#  'contains(rather)': False,
#  'contains(systemwide)': False,
#  'contains(sad)': False,
#  'contains(cking)': False,
#  'contains(0162389030167)': False,
#  'contains(heard)': False,
#  'contains(mountains)': False,
#  'contains(Jurassic)': False,
#  'contains(UA1543)': False,
#  'contains(cousins)': False,
#  'contains(program)': False,
#  'contains(folks)': False,
#  'contains(problem)': False,
#  'contains(scan)': False,
#  "contains('ya)": False,
#  'contains(excited)': False,
#  'contains(reviewed)': False,
#  'contains(up)': False,
#  'contains(ensure)': False,
#  'contains(UA80)': False,
#  'contains(Lady)': False,
#  'contains(experience)': False,
#  'contains(writers)': False,
#  'contains(PIECE)': False,
#  'contains(badges)': False,
#  'contains(can)': False,
#  'contains(attendant)': False,
#  'contains(canned)': False,
#  'contains(legal)': False,
#  'contains(fairs)': False,
#  'contains(39/way)': False,
#  'contains(supporting)': False,
#  'contains(while)': False,
#  'contains(pls)': False,
#  'contains(company)': False,
#  'contains(clothes)': False,
#  'contains(exhausting)': False,
#  'contains(calling)': False,
#  'contains(anyone)': False,
#  'contains(black)': False,
#  'contains(Lesson)': False,
#  'contains(musicians)': False,
#  'contains(Finally)': False,
#  'contains(JAC)': False,
#  'contains(UNACCEPTABLE)': False,
#  'contains(Found)': False,
#  'contains(11th)': False,
#  'contains(International)': False,
#  'contains(8th)': False,
#  'contains(overbook)': False,
#  'contains(responding)': False,
#  'contains(Mileage)': False,
#  'contains(conversion)': False,
#  'contains(feb)': False,
#  'contains(Awful)': False,
#  'contains(control—the)': False,
#  'contains(fuel)': False,
#  'contains(You)': False,
#  'contains(redcarpet)': False,
#  'contains(flown)': False,
#  'contains(feel)': False,
#  'contains(Had)': False,
#  'contains(ZERO)': False,
#  'contains(MelanieSpring)': False,
#  'contains(skiing)': False,
#  'contains(brain)': False,
#  'contains(nada)': False,
#  'contains(doesn)': False,
#  'contains(Soon)': False,
#  'contains(Robin)': False,
#  'contains(B)': False,
#  'contains(Fuck)': False,
#  'contains(Sad)': False,
#  'contains(does)': False,
#  'contains(safety)': False,
#  'contains(attendants)': False,
#  'contains(t.co/lFS4PEFE6y)': False,
#  'contains(747)': False,
#  'contains(5)': False,
#  'contains(stretching)': False,
#  'contains(dedication)': False,
#  'contains(marketing)': False,
#  'contains(cake)': False,
#  'contains(razor)': False,
#  'contains(let)': False,
#  'contains(PREVENT)': False,
#  'contains(luv)': False,
#  'contains(April)': False,
#  'contains(skies)': False,
#  'contains(Stood)': False,
#  'contains(1247)': False,
#  'contains(lady)': False,
#  'contains(BWI)': False,
#  'contains(Thnx)': False,
#  'contains(injured)': False,
#  'contains(500)': False,
#  'contains(shows)': False,
#  'contains(lines)': False,
#  'contains(Need)': False,
#  'contains(need)': False,
#  'contains(services)': False,
#  'contains(Stay)': False,
#  'contains(spotify)': False,
#  'contains(TSA)': False,
#  'contains(agree)': False,
#  'contains(us)': False,
#  'contains(she)': False,
#  'contains(accept)': False,
#  'contains(1k)': False,
#  'contains(crashed)': False,
#  'contains(Plans)': False,
#  'contains(cold)': False,
#  'contains(phone)': False,
#  'contains(ASE)': False,
#  'contains(regulations)': False,
#  'contains(lie)': False,
#  'contains(RenttheRunway)': False,
#  'contains(Direct)': False,
#  'contains(resent)': False,
#  'contains(prove)': False,
#  'contains(However)': False,
#  'contains(adapted)': False,
#  'contains(Glasgow)': False,
#  'contains(unused)': False,
#  'contains(expects)': False,
#  'contains(engine)': False,
#  'contains(nearly)': False,
#  'contains(amongst)': False,
#  'contains(2A)': False,
#  'contains(Q)': False,
#  'contains(acknowledge)': False,
#  'contains(available)': False,
#  'contains(honest)': False,
#  'contains(YES)': False,
#  'contains(Date)': False,
#  'contains(w/others)': False,
#  'contains(😡)': False,
#  'contains(Baggage)': False,
#  'contains(t-minus)': False,
#  'contains(latrice)': False,
#  'contains(knows)': False,
#  'contains(killing)': False,
#  'contains(1B)': False,
#  'contains(letsgohome)': False,
#  'contains(gla-mco)': False,
#  'contains(claim)': False,
#  'contains(an)': False,
#  'contains(properly)': False,
#  'contains(vision)': False,
#  'contains(communication/details)': False,
#  'contains(Sweet)': False,
#  'contains(Exhausted)': False,
#  'contains(Staff)': False,
#  'contains(430am)': False,
#  'contains(shared)': False,
#  'contains(demoted)': False,
#  'contains(Apollochplayers)': False,
#  'contains(SFO)': False,
#  'contains(returning)': False,
#  'contains(U.S)': False,
#  'contains(Lots)': False,
#  'contains(❄️❄️)': False,
#  'contains(CLE-SFO)': False,
#  'contains(WaltDisneyWorld)': False,
#  'contains(Disappointed)': False,
#  'contains(pulling)': False,
#  'contains(refund)': False,
#  'contains(Cc)': False,
#  'contains(hilarious)': False,
#  'contains(BEGGING)': False,
#  'contains(3/31/15)': False,
#  'contains(910)': False,
#  'contains(become)': False,
#  'contains(disrupted)': False,
#  'contains(entire)': False,
#  'contains(Desk)': False,
#  'contains(remedy)': False,
#  'contains(hotspot)': False,
#  'contains(pre-check)': False,
#  'contains(5396)': False,
#  'contains(disconnect)': False,
#  'contains(category)': False,
#  'contains(40-50)': False,
#  'contains(United)': False,
#  'contains(anytime)': False,
#  'contains(777)': False,
#  'contains(stink)': False,
#  'contains(sneaky)': False,
#  'contains(blazer)': False,
#  'contains(‘)': False,
#  'contains(FreeNeverSucks)': False,
#  'contains(copy)': False,
#  'contains(logic)': False,
#  'contains(cabaret)': False,
#  'contains(Continued)': False,
#  'contains(refuses)': False,
#  'contains(winter)': False,
#  'contains(So)': False,
#  'contains(w/25)': False,
#  'contains(rollerboards)': False,
#  'contains(Bruh)': False,
#  'contains(about)': False,
#  'contains(TIMCO)': False,
#  'contains(confirmations)': False,
#  'contains(NewsVP)': False,
#  'contains(1491)': False,
#  'contains(flat)': False,
#  'contains(emailed)': False,
#  'contains(Flightlation)': False,
#  'contains(fucked)': False,
#  'contains(furrow)': False,
#  'contains(avail)': False,
#  'contains(CSR)': False,
#  'contains(lowered)': False,
#  'contains(moms)': False,
#  'contains(fly2ohare)': False,
#  'contains(fan)': False,
#  'contains(looked)': False,
#  'contains(assisting)': False,
#  'contains(882)': False,
#  'contains(Spotty)': False,
#  'contains(whatever)': False,
#  'contains(Handle)': False,
#  'contains(Vibe)': False,
#  'contains(ABOUT)': False,
#  'contains(driving)': False,
#  'contains(2:10pm)': False,
#  'contains(Plane)': False,
#  'contains(Jaramillo)': False,
#  'contains(Passbook)': False,
#  'contains(forcing)': False,
#  'contains(formally)': False,
#  'contains(Forecasts)': False,
#  'contains(t.co/u6Duw27mDE)': False,
#  'contains(sytycd)': False,
#  'contains(pack)': False,
#  'contains(cnxns)': False,
#  'contains(Downgraded)': False,
#  'contains(a)': False,
#  'contains(competes)': False,
#  'contains(t.co/0pRGySvuRm)': False,
#  'contains(change)': False,
#  'contains(Maui)': False,
#  'contains(Follow)': False,
#  'contains(refuse)': False,
#  'contains(enquires)': False,
#  'contains(JMS2802)': False,
#  'contains(wan)': False,
#  'contains(2wks)': False,
#  'contains(surprised)': False,
#  'contains(process)': False,
#  'contains(their)': False,
#  'contains(confirmation)': False,
#  'contains(airlines)': False,
#  'contains(livewelltraveled)': False,
#  'contains(ends)': False,
#  'contains(directly)': False,
#  'contains(funny)': False,
#  'contains(making)': False,
#  'contains(Customer)': False,
#  'contains(brisk)': False,
#  'contains(t.co/lWWdAc2kHx)': False,
#  'contains(checking)': False,
#  'contains(putting)': False,
#  'contains(am)': False,
#  'contains(connect)': False,
#  'contains(fav)': False,
#  'contains(unitedairlines)': False,
#  'contains(Reno)': False,
#  'contains(CA)': False,
#  'contains(way/way)': False,
#  'contains(w/nonworking)': False,
#  'contains(elevate)': False,
#  'contains(JKF)': False,
#  'contains(getaway)': False,
#  'contains(Frigid)': False,
#  'contains(last)': False,
#  'contains(accommodate)': False,
#  'contains(consistent)': False,
#  'contains(married)': False,
#  'contains(Flights)': False,
#  'contains(highbuddyyy)': False,
#  'contains(Cancelled)': False,
#  'contains(horrid)': False,
#  'contains(ripped)': False,
#  'contains(intended)': False,
#  'contains(t.co/APtZpuROp4)': False,
#  'contains(Gives)': False,
#  'contains(placed)': False,
#  'contains(financial)': False,
#  'contains(report)': False,
#  'contains(unrealistic)': False,
#  'contains(upon)': False,
#  'contains(built)': False,
#  'contains(bubbly)': False,
#  'contains(bad)': False,
#  'contains(2-8)': False,
#  'contains(damage)': False,
#  'contains(atl-ord)': False,
#  'contains(note)': False,
#  'contains(notfair)': False,
#  'contains(cleaning)': False,
#  'contains(license)': False,
#  'contains(MCI)': False,
#  'contains(Sked)': False,
#  'contains(nope)': False,
#  'contains(l8r)': False,
#  'contains(issue)': False,
#  'contains(celebrating)': False,
#  'contains(To)': False,
#  'contains(connecting)': False,
#  'contains(reaching)': False,
#  'contains(Tried)': False,
#  'contains(land)': False,
#  'contains(Daily)': False,
#  'contains(6th)': False,
#  'contains(overhead)': False,
#  'contains(This)': False,
#  'contains(8719519)': False,
#  'contains(Ugh)': False,
#  'contains(integrate)': False,
#  'contains(use)': False,
#  'contains(focused)': False,
#  'contains(man)': False,
#  'contains(Brussels)': False,
#  'contains(aware)': False,
#  'contains(faith)': False,
#  'contains(1758)': False,
#  'contains(All)': False,
#  'contains(AND)': False,
#  'contains(rows)': False,
#  'contains(set)': False,
#  'contains(walked)': False,
#  'contains(1st)': False,
#  'contains(t.co/FVUdmh27pF)': False,
#  'contains(Baby)': False,
#  'contains(Paul)': False,
#  'contains(abt)': False,
#  'contains(prior)': False,
#  'contains(THE)': False,
#  'contains(sarcasm)': False,
#  'contains(stewardess)': False,
#  'contains(Acosta)': False,
#  'contains(catching)': False,
#  'contains(413)': False,
#  'contains(awhile)': False,
#  'contains(access)': False,
#  'contains(9:08)': False,
#  'contains(HelpImStuck)': False,
#  'contains(Faire)': False,
#  'contains(1stClass)': False,
#  'contains(mention)': False,
#  'contains(case)': False,
#  'contains(goes)': False,
#  'contains(power)': False,
#  'contains(nonstop)': False,
#  'contains(unpleased)': False,
#  'contains(bid)': False,
#  'contains(because)': False,
#  'contains(YOUR)': False,
#  'contains(BOS-LAS)': False,
#  'contains(partner)': False,
#  'contains(FB)': False,
#  'contains(life)': False,
#  'contains(carry)': False,
#  'contains(703)': False,
#  'contains(bounce)': False,
#  'contains(went)': False,
#  'contains(Waiting)': False,
#  'contains(ridiculous)': False,
#  'contains(replacement)': False,
#  'contains(leading)': False,
#  'contains(Atlantic)': False,
#  'contains(central)': False,
#  'contains(hung)': False,
#  'contains(always)': False,
#  'contains(PoorService)': False,
#  'contains(paying)': False,
#  "contains('on)": False,
#  'contains(delayed-no)': False,
#  'contains(Hold)': False,
#  'contains(aaaand)': False,
#  'contains(Field)': False,
#  'contains(Club)': False,
#  'contains(family)': False,
#  'contains(pink)': False,
#  'contains(doctor)': False,
#  'contains(UA871)': False,
#  'contains(voided)': False,
#  'contains(neverflyvirginforbusiness)': False,
#  'contains(VXSafetyDance)': False,
#  'contains(MY8YB4)': False,
#  'contains(4C)': False,
#  'contains(de-icing)': False,
#  'contains(unrivalled)': False,
#  'contains(Left)': False,
#  'contains(bumping)': False,
#  'contains(Fargo)': False,
#  'contains(expected)': False,
#  'contains(Turn)': False,
#  'contains(above)': False,
#  'contains(feedback)': False,
#  'contains(id)': False,
#  'contains(w/a)': False,
#  'contains(going)': False,
#  'contains(Comenity)': False,
#  'contains(worked)': False,
#  'contains(American)': False,
#  'contains(outbound)': False,
#  'contains(frankly)': False,
#  'contains(Lisa)': False,
#  'contains(ual)': False,
#  'contains(ws)': False,
#  'contains(Lounge)': False,
#  'contains(important)': False,
#  'contains(2/24)': False,
#  'contains(t.co/5B2agFd8c4)': False,
#  'contains(STARBUCKS)': False,
#  'contains(few)': False,
#  'contains(stunned)': False,
#  'contains(negligence)': False,
#  'contains(Pilot)': False,
#  'contains(Calls)': False,
#  'contains(TV)': False,
#  'contains(knack)': False,
#  'contains(Singapore)': False,
#  'contains(🌞✈)': False,
#  'contains(lbs)': False,
#  'contains(maybe)': False,
#  'contains(Birthdate)': False,
#  'contains(sunglasses)': False,
#  'contains(beginning)': False,
#  'contains(curious)': False,
#  'contains(promise)': False,
#  'contains(HelpMePlease)': False,
#  'contains(amazing)': False,
#  'contains(retrieve)': False,
#  'contains(Narayanan)': False,
#  'contains(him)': False,
#  'contains(overweight)': False,
#  'contains(Lake)': False,
#  'contains(Every)': False,
#  'contains(according)': False,
#  'contains(shattered)': False,
#  'contains(👍👍✈️✈️💗)': False,
#  'contains(Neurosurgery)': False,
#  'contains(Grand)': False,
#  'contains(advertise)': False,
#  'contains(reccewife)': False,
#  'contains(child)': False,
#  'contains(friend)': False,
#  'contains(intact)': False,
#  'contains(EU)': False,
#  'contains(1)': False,
#  'contains(tonight)': False,
#  'contains(spoke)': False,
#  'contains(sfo2lax)': False,
#  'contains(devalue)': False,
#  'contains(Airways)': False,
#  'contains(☺️👍)': False,
#  'contains(returned)': False,
#  'contains(century)': False,
#  'contains(Upgrade)': False,
#  'contains(generic)': False,
#  'contains(nogate)': False,
#  'contains(subsequent)': False,
#  'contains(LESS)': False,
#  'contains(t.co/96Sctomh29)': False,
#  'contains(terribly)': False,
#  'contains(Like)': False,
#  'contains(Let)': False,
#  'contains(delivered)': False,
#  'contains(worthless)': False,
#  'contains(virginamerica)': False,
#  'contains(thankfully)': False,
#  'contains(measure)': False,
#  'contains(send)': False,
#  'contains(Colo)': False,
#  'contains(Want)': False,
#  'contains(ball)': False,
#  'contains(17)': False,
#  'contains(tiredofwaiting)': False,
#  'contains(braving)': False,
#  'contains(cards)': False,
#  'contains(Adding)': False,
#  'contains(💗🇬🇧💗🇺🇸💗)': False,
#  'contains(certainly)': False,
#  'contains(Seductive)': False,
#  'contains(Doctors)': False,
#  'contains(sleep.But)': False,
#  'contains(Karen)': False,
#  'contains(regulation)': False,
#  'contains(BOM)': False,
#  'contains(extremely)': False,
#  'contains(unacceptable)': False,
#  'contains(t.co/gA8pbamu0C)': False,
#  'contains(Malaysia)': False,
#  'contains(advantage)': False,
#  'contains(showing)': False,
#  'contains(beverage)': False,
#  'contains(enjoyed)': False,
#  'contains(Palm)': False,
#  'contains(RECEIVED)': False,
#  'contains(mine)': False,
#  'contains(top)': False,
#  'contains(LA)': False,
#  'contains(flight🍸)': False,
#  'contains(UA1270)': False,
#  'contains(634)': False,
#  'contains(DangerOfGettingSnowedIn)': False,
#  'contains(rsw)': False,
#  'contains(bothered)': False,
#  'contains(check)': False,
#  'contains(proper)': False,
#  'contains(enforcement)': False,
#  'contains(fixed)': False,
#  'contains(WOAW)': False,
#  'contains(pilot)': False,
#  'contains(terrible)': False,
#  'contains(construction)': False,
#  'contains(dislike)': False,
#  'contains(single)': False,
#  'contains(MCO)': False,
#  'contains(online)': False,
#  'contains(towards)': False,
#  'contains(arriving)': False,
#  'contains(UAL)': False,
#  'contains(LOVE)': False,
#  'contains(moose)': False,
#  'contains(Woke)': False,
#  'contains(courrier)': False,
#  'contains(Huh)': False,
#  'contains(job)': False,
#  'contains(night)': False,
#  'contains(Xoxo)': False,
#  'contains(Ok)': False,
#  'contains(security)': False,
#  'contains(ATL)': False,
#  'contains(pepper)': False,
#  'contains(raise)': False,
#  'contains(none)': False,
#  'contains(help)': False,
#  'contains(anywhere)': False,
#  'contains(THANK)': False,
#  'contains(AirCanada)': False,
#  'contains(intl)': False,
#  'contains(further)': False,
#  'contains(turn)': False,
#  'contains(From)': False,
#  'contains(rules)': False,
#  'contains(dissapointment)': False,
#  'contains(fine)': False,
#  'contains(276)': False,
#  'contains(visa)': False,
#  'contains(dm)': False,
#  'contains(revisiting)': False,
#  'contains(my)': False,
#  'contains(MeetTheFleet)': False,
#  'contains(Placing)': False,
#  'contains(overbooked)': False,
#  'contains(STEP)': False,
#  'contains(3hrs)': False,
#  'contains(Holla)': False,
#  'contains(SuuperG)': False,
#  'contains(thrilled)': False,
#  'contains(t.co/r8p2Zy3fe4)': False,
#  'contains(Love/gratitude.mpower)': False,
#  'contains(travelers)': False,
#  'contains(umpteen)': False,
#  'contains(ceo)': False,
#  'contains(cun)': False,
#  'contains(gross)': False,
#  'contains(UnFriendlySkies)': False,
#  'contains(load)': False,
#  'contains(tuned)': False,
#  'contains(aeroport)': False,
#  'contains(nominated)': False,
#  'contains(member😒)': False,
#  'contains(Kooples)': False,
#  'contains(frozen)': False,
#  'contains(courtesy)': False,
#  'contains(strategy)': False,
#  'contains(thurs)': False,
#  'contains(Belfast)': False,
#  'contains(choosing)': False,
#  'contains(UA23)': False,
#  'contains(friendlyskies)': False,
#  'contains(neglect)': False,
#  'contains(awaiting)': False,
#  'contains(link)': False,
#  'contains(Hotel)': False,
#  'contains(tacky)': False,
#  'contains(glitch)': False,
#  'contains(sun)': False,
#  'contains(Luggage)': False,
#  'contains(Going)': False,
#  'contains(spread)': False,
#  'contains(UA6366)': False,
#  'contains(ETA)': False,
#  'contains(Fix)': False,
#  'contains(bounces)': False,
#  'contains(demo)': False,
#  'contains(Arriving)': False,
#  'contains(Business)': False,
#  'contains(inconvenient)': False,
#  'contains(WMASS)': False,
#  'contains(panicked)': False,
#  'contains(controlled)': False,
#  'contains(Dallas_News)': False,
#  'contains(among)': False,
#  'contains(barely)': False,
#  "contains(n't)": False,
#  'contains(Any)': False,
#  'contains(considering)': False,
#  'contains(UA862)': False,
#  'contains(salvaged)': False,
#  'contains(GATE)': False,
#  'contains(talk)': False,
#  'contains(Darquenloveli)': False,
#  'contains(strangers)': False,
#  'contains(storm)': False,
#  'contains(Jersey)': False,
#  'contains(Sat)': False,
#  'contains(using)': False,
#  'contains(wing)': False,
#  'contains(Sprint)': False,
#  'contains(remorse)': False,
#  'contains(clue)': False,
#  'contains(Lovely)': False,
#  'contains(There)': False,
#  'contains(auto)': False,
#  'contains(Luckily)': False,
#  'contains(stuff)': False,
#  'contains(t.co/2pUJvCElNg)': False,
#  'contains(w/our)': False,
#  'contains(control)': False,
#  'contains(lineup)': False,
#  'contains(uncomfortable)': False,
#  'contains(filled)': False,
#  'contains(hotelliving)': False,
#  'contains(MONEY)': False,
#  'contains(headed)': False,
#  'contains(cutest)': False,
#  'contains(foot)': False,
#  'contains(y)': False,
#  'contains(Guess)': False,
#  'contains(t.co/8qsQMM7KF2)': False,
#  'contains(Applied)': False,
#  'contains(onto)': False,
#  'contains(damper)': False,
#  'contains(rise)': False,
#  'contains(disappointed)': False,
#  'contains(freaked)': False,
#  'contains(Mon)': False,
#  'contains(coach)': False,
#  'contains(read)': False,
#  'contains(Per)': False,
#  'contains(😍👌)': False,
#  'contains(t.co/zCBJyo6lsN)': False,
#  'contains(playing)': False,
#  'contains(book)': False,
#  'contains(lap)': False,
#  'contains(taxis)': False,
#  'contains(RDU)': False,
#  'contains(FYVRFN)': False,
#  'contains(EWR-BRU-DEL)': False,
#  'contains(complained)': False,
#  'contains(Unfortunate)': False,
#  'contains(allowed)': False,
#  'contains(sarcastically)': False,
#  'contains(Flightlations)': False,
#  'contains(maintenance)': False,
#  'contains(counter)': False,
#  'contains(t.co/cIh1qNllcM)': False,
#  'contains(t.co/xRdTOV7nl8)': False,
#  'contains(AV)': False,
#  'contains(booted)': False,
#  'contains(attempting)': False,
#  'contains(win)': False,
#  'contains(CMH)': False,
#  'contains(earned)': False,
#  'contains(reserv)': False,
#  'contains(costs)': False,
#  'contains(t.co/sUPrLfOi8T)': False,
#  'contains(expires)': False,
#  'contains(less)': False,
#  'contains(seriousness)': False,
#  'contains(slots)': False,
#  'contains(much)': False,
#  'contains(n)': False,
#  'contains(ticket)': False,
#  'contains(Flt)': False,
#  'contains(destination)': False,
#  'contains(bank)': False,
#  'contains(t.co/CqMm7nuE9m)': False,
#  'contains(6-year-old)': False,
#  'contains(6:20)': False,
#  'contains(adjacent)': False,
#  'contains(suggest)': False,
#  'contains(Q4)': False,
#  'contains(accident)': False,
#  'contains(seem)': False,
#  'contains(seatback)': False,
#  'contains(plans)': False,
#  'contains(Im)': False,
#  'contains(ZRH_airport)': False,
#  'contains(PQD)': False,
#  'contains(class)': False,
#  'contains(tickets)': False,
#  'contains(helpful)': False,
#  'contains(intro)': False,
#  'contains(CPAP)': False,
#  'contains(t.co/pPVA4Rch9f)': False,
#  'contains(giannilee)': False,
#  'contains(potentially)': False,
#  'contains(VirginAtlantic)': False,
#  'contains(cs)': False,
#  'contains(tsk)': False,
#  'contains(AspenBaggageFail)': False,
#  'contains(1/2)': False,
#  'contains(4Q)': False,
#  'contains(moved)': False,
#  'contains(ON)': False,
#  'contains(AN)': False,
#  'contains(officially)': False,
#  'contains(t.co/XWJoL55FLH)': False,
#  'contains(Winston)': False,
#  'contains(esp)': False,
#  'contains(cabin)': False,
#  'contains(ATWOnline)': False,
#  'contains(encourage)': False,
#  'contains(rockinwellness)': False,
#  'contains(caused)': False,
#  'contains(check-in)': False,
#  'contains(I)': True,
#  'contains(worried)': False,
#  'contains(worrying)': False,
#  'contains(MaryJo)': False,
#  'contains(departure)': False,
#  'contains(terribleservice)': False,
#  'contains(good)': False,
#  'contains(112)': False,
#  'contains(LizaUtter)': False,
#  'contains(understatement)': False,
#  'contains(G)': False,
#  'contains(Results)': False,
#  'contains(falling)': False,
#  'contains(Cancun)': False,
#  'contains(obsessed)': False,
#  'contains(giving)': False,
#  'contains(stressful)': False,
#  'contains(75)': False,
#  'contains(unhappy)': False,
#  'contains(Ph)': False,
#  'contains(t.co/ZfqMpGXVS6)': False,
#  'contains(absurd)': False,
#  'contains(3:30)': False,
#  'contains(Three)': False,
#  'contains(views)': False,
#  'contains(yelling)': False,
#  'contains(begin)': False,
#  'contains(jacked)': False,
#  'contains(WORST)': False,
#  'contains(item)': False,
#  'contains(track)': False,
#  'contains(Mexico)': False,
#  'contains(disaster)': False,
#  'contains(MR)': False,
#  'contains(BTW)': False,
#  'contains(voucher)': False,
#  'contains(improvement)': False,
#  'contains(centers)': False,
#  'contains(1032)': False,
#  'contains(momma)': False,
#  'contains(kits)': False,
#  'contains(23OCT)': False,
#  'contains(out)': False,
#  'contains(14)': False,
#  'contains(course)': False,
#  'contains(advertised)': False,
#  'contains(tactic)': False,
#  'contains(3511)': False,
#  'contains(msg)': False,
#  'contains(t.co/B2Xi4YG5T8)': False,
#  'contains(little)': False,
#  'contains(worse)': False,
#  'contains(incls)': False,
#  'contains(connector)': False,
#  'contains(huh)': False,
#  'contains(ads)': False,
#  'contains(Ridiculous)': False,
#  'contains(acct)': False,
#  'contains(point)': False,
#  "contains(didn't…but)": False,
#  'contains(calming)': False,
#  'contains(both)': False,
#  'contains(1585)': False,
#  'contains(passengers)': False,
#  'contains(ua3576)': False,
#  'contains(Held)': False,
#  'contains(h)': False,
#  'contains(filed)': False,
#  'contains(ten)': False,
#  'contains(old)': False,
#  'contains(scanned)': False,
#  'contains(vouchers)': False,
#  'contains(TelAviv)': False,
#  'contains(medal)': False,
#  'contains(SBA)': False,
#  'contains(VirginAmerica)': False,
#  'contains(27D)': False,
#  'contains(refusing)': False,
#  'contains(8am)': False,
#  'contains(graphic)': False,
#  'contains(Cleveland)': False,
#  'contains(Gf)': False,
#  'contains(lone)': False,
#  'contains(SheRocks)': False,
#  'contains(savings)': False,
#  'contains(SERV)': False,
#  'contains(DISAPPOINTED)': False,
#  'contains(prolly)': False,
#  'contains(Wo)': False,
#  'contains(spare)': False,
#  'contains(BG0KWM)': False,
#  'contains(SFOtoBOS)': False,
#  'contains(ran)': False,
#  'contains(preboarding)': False,
#  'contains(wet)': False,
#  'contains(fat)': False,
#  'contains(monitor)': False,
#  'contains(bouncer)': False,
#  'contains(Include)': False,
#  'contains(meet)': False,
#  'contains(evening)': False,
#  'contains(duffle)': False,
#  'contains(AmericanAir)': False,
#  'contains(perfect)': False,
#  'contains(39)': False,
#  'contains(Come)': False,
#  'contains(bill)': False,
#  'contains(singer)': False,
#  'contains(Terri)': False,
#  'contains(debacle)': False,
#  'contains(seeking)': False,
#  'contains(8465981)': False,
#  'contains(now)': False,
#  'contains(assaulted)': False,
#  'contains(end)': False,
#  'contains(AU1066)': False,
#  'contains(extra)': False,
#  'contains(madbee95)': False,
#  'contains(managed)': False,
#  'contains(sf)': False,
#  'contains(inconveniently)': False,
#  'contains(certain)': False,
#  'contains(airfare)': False,
#  'contains(Dear)': False,
#  'contains(Shame)': False,
#  'contains(supervisor)': False,
#  'contains(MEX)': False,
#  'contains(1212)': False,
#  'contains(moodlight)': False,
#  'contains(enroll)': False,
#  'contains(every)': False,
#  'contains(550)': False,
#  'contains(Grandma)': False,
#  'contains(truly)': False,
#  "contains(Y'all)": False,
#  'contains(fucking)': False,
#  ...}

# %%
# Classifying From Within a TextBlob
# We can perform classification on the contents of a TextBlob object using an existing classifier (like the one we created earlier (named cl). The usefulness of this might seem questionable, since you can just pass a normal string to the classifier. However, something you will be doing other work with some text in the form of a blob, and then when you need to perform classification, you don't have to go back and get the raw string.

# Using a clssifier in a TextBlob is as easy as passing the classifier as an argument when you create the blob.

# Note: The classifier must be one that you have already trained.

# Let's look at a couple examples:

b = TextBlob('I loved the flight', classifier=cl)
b.classify()
# Out:
# 'negative'

# %%
b = TextBlob('I hated the flight', classifier=cl)
b.classify()

# Our classifier probably didn't encounter the word "hate" or "hated". We can update our model to improve classification.
# Out:
# 'neutral'

# %%
# Update Existing Classifiers With New Data
# Our classifier obviously failed us when we tried to classify the string "I hate this flight." We have the option of easily updating our classifier with new data, so let's do that now.

# new data is also a list of tuples
# be sure the class labels are correct
updates = [('I hated flying', 'negative'), ('I hate flying', 'negative'),
           ('I hate this airline', 'negative'), ('I hated the seats', 'negative')]
cl.update(updates)  # this is unfortunately slow

# You can ignore the output True
# Note: If you get the error too many values to unpack (expected 2), try re-running the cell where we created the train/test sets and create/train the classifier from scratch.
# Out:
# True

# %%
# Now that we have updated our classifier with new data, let's see how our original sentence is classified.
# let's see how it does now using 'I hated the flight'
b = TextBlob('I hated the flight', classifier=cl) # update
b.classify()

# An now we have the correct classification of 'negative'
# If you do not get the correct class, try running the update cell once more.

# Other Classifiers
# TextBlob has a number of built in classifiers, all of which can be found in the documentation at the link below.

# http://textblob.readthedocs.io/en/dev/api_reference.html#api-classifiers
# Out:
# 'negative'
